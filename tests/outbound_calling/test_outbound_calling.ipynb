# %%
import os
from twilio.rest import Client
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
url = "https://zoo-carolina-format-favorites.trycloudflare.com"  
account_sid = os.getenv("TWILIO_ACCOUNT_SID")
auth_token = os.getenv("TWILIO_AUTH_TOKEN")
client = Client(account_sid, auth_token)

call = client.calls.create(
  #url=f"{url}/voice.xml",
  twiml="<Response><Say>what's up babe...</Say><Play>http://demo.twilio.com/docs/classic.mp3</Play></Response>",
  #twiml='<Response><Connect><Stream url="https://serving-scripts-olympics-roy.trycloudflare.com"/></Connect></Response>',
  to=os.getenv("ALINA_PHONE_NUMBER"),
  from_="+12295141318"
)

print(f"Call SID: {call.sid}")
# Out:
# Call SID: CAba0c35dcb40ef0871dffafe0ca42ab4c
